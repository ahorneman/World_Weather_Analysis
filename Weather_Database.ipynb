# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
import random
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 625

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    # print(city_url)
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # print(city_weather)
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_descript = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": city_descript}
                          )
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mahebourg
# Processing Record 2 of Set 1 | torbay
# Processing Record 3 of Set 1 | oktyabrskoye
# Processing Record 4 of Set 1 | bam
# Processing Record 5 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 7 of Set 1 | toumodi
# Processing Record 8 of Set 1 | isangel
# Processing Record 9 of Set 1 | port alfred
# Processing Record 10 of Set 1 | hamilton
# Processing Record 11 of Set 1 | harper
# Processing Record 12 of Set 1 | cockburn harbour
# City not found. Skipping...
# Processing Record 13 of Set 1 | east london
# Processing Record 14 of Set 1 | saldanha
# Processing Record 15 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 1 | tuatapere
# Processing Record 17 of Set 1 | marmora
# Processing Record 18 of Set 1 | hermanus
# Processing Record 19 of Set 1 | guanica
# Processing Record 20 of Set 1 | cayenne
# Processing Record 21 of Set 1 | fuerte olimpo
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | kaitangata
# Processing Record 24 of Set 1 | tuktoyaktuk
# Processing Record 25 of Set 1 | kapaa
# Processing Record 26 of Set 1 | wajima
# Processing Record 27 of Set 1 | hobart
# Processing Record 28 of Set 1 | sao jose da coroa grande
# Processing Record 29 of Set 1 | husavik
# Processing Record 30 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 31 of Set 1 | talara
# Processing Record 32 of Set 1 | rikitea
# Processing Record 33 of Set 1 | sumbe
# Processing Record 34 of Set 1 | hilo
# Processing Record 35 of Set 1 | abhar
# Processing Record 36 of Set 1 | mataura
# Processing Record 37 of Set 1 | albany
# Processing Record 38 of Set 1 | cockburn town
# Processing Record 39 of Set 1 | vila franca do campo
# Processing Record 40 of Set 1 | atuona
# Processing Record 41 of Set 1 | new norfolk
# Processing Record 42 of Set 1 | samana
# Processing Record 43 of Set 1 | santa maria
# Processing Record 44 of Set 1 | fortuna
# Processing Record 45 of Set 1 | pevek
# Processing Record 46 of Set 1 | lisakovsk
# Processing Record 47 of Set 1 | wagar
# Processing Record 48 of Set 1 | kodiak
# Processing Record 49 of Set 1 | impfondo
# Processing Record 50 of Set 1 | englehart
# Processing Record 1 of Set 2 | kutum
# Processing Record 2 of Set 2 | spring hill
# Processing Record 3 of Set 2 | tulsa
# Processing Record 4 of Set 2 | avarua
# Processing Record 5 of Set 2 | marsh harbour
# Processing Record 6 of Set 2 | kahului
# Processing Record 7 of Set 2 | sao filipe
# Processing Record 8 of Set 2 | arras
# Processing Record 9 of Set 2 | norman wells
# Processing Record 10 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 11 of Set 2 | hambantota
# Processing Record 12 of Set 2 | codrington
# Processing Record 13 of Set 2 | qaanaaq
# Processing Record 14 of Set 2 | victoria
# Processing Record 15 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 2 | itarema
# Processing Record 17 of Set 2 | lompoc
# Processing Record 18 of Set 2 | price
# Processing Record 19 of Set 2 | ketchikan
# Processing Record 20 of Set 2 | kitimat
# Processing Record 21 of Set 2 | san cristobal
# Processing Record 22 of Set 2 | bredasdorp
# Processing Record 23 of Set 2 | zadar
# Processing Record 24 of Set 2 | ushuaia
# Processing Record 25 of Set 2 | mogadishu
# Processing Record 26 of Set 2 | melioratorov
# Processing Record 27 of Set 2 | aleppo
# Processing Record 28 of Set 2 | north bend
# Processing Record 29 of Set 2 | altagracia de orituco
# Processing Record 30 of Set 2 | churapcha
# Processing Record 31 of Set 2 | grindavik
# Processing Record 32 of Set 2 | kupang
# Processing Record 33 of Set 2 | tres picos
# Processing Record 34 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 35 of Set 2 | ribas do rio pardo
# Processing Record 36 of Set 2 | bandarbeyla
# Processing Record 37 of Set 2 | punta arenas
# Processing Record 38 of Set 2 | bagdarin
# Processing Record 39 of Set 2 | north las vegas
# Processing Record 40 of Set 2 | ribeira grande
# Processing Record 41 of Set 2 | puerto ayora
# Processing Record 42 of Set 2 | beringovskiy
# Processing Record 43 of Set 2 | maralal
# Processing Record 44 of Set 2 | yar-sale
# Processing Record 45 of Set 2 | narsaq
# Processing Record 46 of Set 2 | brwinow
# Processing Record 47 of Set 2 | huarmey
# Processing Record 48 of Set 2 | deputatskiy
# Processing Record 49 of Set 2 | bonavista
# Processing Record 50 of Set 2 | antonina
# Processing Record 1 of Set 3 | griffith
# Processing Record 2 of Set 3 | cape town
# Processing Record 3 of Set 3 | ponta do sol
# Processing Record 4 of Set 3 | castro
# Processing Record 5 of Set 3 | tiksi
# Processing Record 6 of Set 3 | sitka
# Processing Record 7 of Set 3 | karachi
# Processing Record 8 of Set 3 | dunedin
# Processing Record 9 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 3 | nome
# Processing Record 11 of Set 3 | georgetown
# Processing Record 12 of Set 3 | saint-louis
# Processing Record 13 of Set 3 | xingyi
# Processing Record 14 of Set 3 | arraial do cabo
# Processing Record 15 of Set 3 | zhanaozen
# Processing Record 16 of Set 3 | buala
# Processing Record 17 of Set 3 | nouadhibou
# Processing Record 18 of Set 3 | bazpur
# Processing Record 19 of Set 3 | jamestown
# Processing Record 20 of Set 3 | caravelas
# Processing Record 21 of Set 3 | gizo
# Processing Record 22 of Set 3 | iqaluit
# Processing Record 23 of Set 3 | bulgan
# Processing Record 24 of Set 3 | butaritari
# Processing Record 25 of Set 3 | ballyhaunis
# Processing Record 26 of Set 3 | tasiilaq
# Processing Record 27 of Set 3 | ambon
# Processing Record 28 of Set 3 | hithadhoo
# Processing Record 29 of Set 3 | key largo
# Processing Record 30 of Set 3 | mar del plata
# Processing Record 31 of Set 3 | ostrovnoy
# Processing Record 32 of Set 3 | cordoba
# Processing Record 33 of Set 3 | saint-philippe
# Processing Record 34 of Set 3 | iquique
# Processing Record 35 of Set 3 | chokurdakh
# Processing Record 36 of Set 3 | arzgir
# Processing Record 37 of Set 3 | leningradskiy
# Processing Record 38 of Set 3 | wajid
# Processing Record 39 of Set 3 | westport
# Processing Record 40 of Set 3 | kruisfontein
# Processing Record 41 of Set 3 | necochea
# Processing Record 42 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 3 | constitucion
# Processing Record 44 of Set 3 | esperance
# Processing Record 45 of Set 3 | banda aceh
# Processing Record 46 of Set 3 | birao
# Processing Record 47 of Set 3 | dukat
# Processing Record 48 of Set 3 | vao
# Processing Record 49 of Set 3 | thompson
# Processing Record 50 of Set 3 | dikson
# Processing Record 1 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 4 | manta
# Processing Record 3 of Set 4 | veraval
# Processing Record 4 of Set 4 | marawi
# Processing Record 5 of Set 4 | bethel
# Processing Record 6 of Set 4 | kavaratti
# Processing Record 7 of Set 4 | vaini
# Processing Record 8 of Set 4 | vila velha
# Processing Record 9 of Set 4 | pokrovsk
# Processing Record 10 of Set 4 | bengkulu
# Processing Record 11 of Set 4 | saskylakh
# Processing Record 12 of Set 4 | asau
# Processing Record 13 of Set 4 | basqal
# Processing Record 14 of Set 4 | okato
# Processing Record 15 of Set 4 | port elizabeth
# Processing Record 16 of Set 4 | half moon bay
# Processing Record 17 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 18 of Set 4 | voyvozh
# Processing Record 19 of Set 4 | acarau
# Processing Record 20 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 4 | kavieng
# Processing Record 22 of Set 4 | lebu
# Processing Record 23 of Set 4 | ancud
# Processing Record 24 of Set 4 | cervo
# Processing Record 25 of Set 4 | barrow
# Processing Record 26 of Set 4 | gubkinskiy
# Processing Record 27 of Set 4 | marsa matruh
# Processing Record 28 of Set 4 | bembereke
# Processing Record 29 of Set 4 | maracacume
# Processing Record 30 of Set 4 | talnakh
# Processing Record 31 of Set 4 | varna
# Processing Record 32 of Set 4 | viransehir
# Processing Record 33 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 4 | ambilobe
# Processing Record 35 of Set 4 | hami
# Processing Record 36 of Set 4 | jardim
# Processing Record 37 of Set 4 | bluff
# Processing Record 38 of Set 4 | khatanga
# Processing Record 39 of Set 4 | manggar
# Processing Record 40 of Set 4 | faanui
# Processing Record 41 of Set 4 | hegang
# Processing Record 42 of Set 4 | ahuimanu
# Processing Record 43 of Set 4 | safranbolu
# Processing Record 44 of Set 4 | sheregesh
# Processing Record 45 of Set 4 | coihaique
# Processing Record 46 of Set 4 | avera
# Processing Record 47 of Set 4 | airai
# Processing Record 48 of Set 4 | cidreira
# Processing Record 49 of Set 4 | penzance
# Processing Record 50 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 1 of Set 5 | dali
# Processing Record 2 of Set 5 | castelldefels
# Processing Record 3 of Set 5 | amnat charoen
# Processing Record 4 of Set 5 | atambua
# Processing Record 5 of Set 5 | anadyr
# Processing Record 6 of Set 5 | sisimiut
# Processing Record 7 of Set 5 | bambous virieux
# Processing Record 8 of Set 5 | meulaboh
# Processing Record 9 of Set 5 | millinocket
# Processing Record 10 of Set 5 | port hardy
# Processing Record 11 of Set 5 | surt
# Processing Record 12 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 13 of Set 5 | saint anthony
# Processing Record 14 of Set 5 | namatanai
# Processing Record 15 of Set 5 | verkhnyaya inta
# Processing Record 16 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 17 of Set 5 | dhidhdhoo
# Processing Record 18 of Set 5 | borama
# City not found. Skipping...
# Processing Record 19 of Set 5 | sao raimundo das mangabeiras
# Processing Record 20 of Set 5 | tarauaca
# Processing Record 21 of Set 5 | dudinka
# Processing Record 22 of Set 5 | salinas
# Processing Record 23 of Set 5 | yellowknife
# Processing Record 24 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 25 of Set 5 | almunecar
# Processing Record 26 of Set 5 | le port
# Processing Record 27 of Set 5 | nipawin
# Processing Record 28 of Set 5 | jiddah
# City not found. Skipping...
# Processing Record 29 of Set 5 | mabaruma
# Processing Record 30 of Set 5 | provideniya
# Processing Record 31 of Set 5 | touros
# Processing Record 32 of Set 5 | manica
# Processing Record 33 of Set 5 | cascavel
# Processing Record 34 of Set 5 | cacahoatan
# Processing Record 35 of Set 5 | turukhansk
# Processing Record 36 of Set 5 | flinders
# Processing Record 37 of Set 5 | posse
# Processing Record 38 of Set 5 | tarakan
# Processing Record 39 of Set 5 | nikolskoye
# Processing Record 40 of Set 5 | longyearbyen
# Processing Record 41 of Set 5 | fairbanks
# Processing Record 42 of Set 5 | santa cruz verapaz
# Processing Record 43 of Set 5 | waipawa
# Processing Record 44 of Set 5 | graaff-reinet
# Processing Record 45 of Set 5 | gurskoye
# City not found. Skipping...
# Processing Record 46 of Set 5 | port lincoln
# Processing Record 47 of Set 5 | mount gambier
# Processing Record 48 of Set 5 | celestun
# Processing Record 49 of Set 5 | panguipulli
# Processing Record 50 of Set 5 | cherskiy
# Processing Record 1 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 2 of Set 6 | puerto gaitan
# Processing Record 3 of Set 6 | puerto escondido
# Processing Record 4 of Set 6 | fort payne
# Processing Record 5 of Set 6 | miri
# Processing Record 6 of Set 6 | saint-pierre
# Processing Record 7 of Set 6 | karratha
# Processing Record 8 of Set 6 | yulara
# Processing Record 9 of Set 6 | aksu
# Processing Record 10 of Set 6 | sondershausen
# Processing Record 11 of Set 6 | chicama
# Processing Record 12 of Set 6 | tiznit
# Processing Record 13 of Set 6 | bontang
# Processing Record 14 of Set 6 | geraldton
# Processing Record 15 of Set 6 | sri aman
# Processing Record 16 of Set 6 | songjianghe
# Processing Record 17 of Set 6 | chuy
# Processing Record 18 of Set 6 | channel-port aux basques
# Processing Record 19 of Set 6 | camacha
# Processing Record 20 of Set 6 | erenhot
# Processing Record 21 of Set 6 | kindu
# Processing Record 22 of Set 6 | sobolevo
# Processing Record 23 of Set 6 | tamazulapam
# City not found. Skipping...
# Processing Record 24 of Set 6 | sampit
# Processing Record 25 of Set 6 | notre-dame-du-lac
# Processing Record 26 of Set 6 | burkhala
# City not found. Skipping...
# Processing Record 27 of Set 6 | san quintin
# Processing Record 28 of Set 6 | torva
# Processing Record 29 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 30 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 31 of Set 6 | saint george
# Processing Record 32 of Set 6 | goderich
# Processing Record 33 of Set 6 | bom jesus
# Processing Record 34 of Set 6 | ilhabela
# Processing Record 35 of Set 6 | kazachinskoye
# Processing Record 36 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 6 | samarai
# Processing Record 38 of Set 6 | carnarvon
# Processing Record 39 of Set 6 | dekoa
# City not found. Skipping...
# Processing Record 40 of Set 6 | phonhong
# Processing Record 41 of Set 6 | dunmore town
# Processing Record 42 of Set 6 | lorengau
# Processing Record 43 of Set 6 | yanan
# City not found. Skipping...
# Processing Record 44 of Set 6 | santa marta
# Processing Record 45 of Set 6 | ayia anna
# Processing Record 46 of Set 6 | yumen
# Processing Record 47 of Set 6 | hays
# Processing Record 48 of Set 6 | gasa
# Processing Record 49 of Set 6 | aklavik
# Processing Record 50 of Set 6 | alyangula
# Processing Record 1 of Set 7 | abha
# Processing Record 2 of Set 7 | shubarkuduk
# Processing Record 3 of Set 7 | fuzhou
# Processing Record 4 of Set 7 | quatre cocos
# Processing Record 5 of Set 7 | ilulissat
# Processing Record 6 of Set 7 | padang
# Processing Record 7 of Set 7 | plyussa
# Processing Record 8 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 7 | luderitz
# Processing Record 10 of Set 7 | pisco
# Processing Record 11 of Set 7 | atar
# Processing Record 12 of Set 7 | somers
# Processing Record 13 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 7 | tete
# Processing Record 15 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 16 of Set 7 | vostok
# Processing Record 17 of Set 7 | dawlatabad
# Processing Record 18 of Set 7 | palomares
# Processing Record 19 of Set 7 | sayat
# Processing Record 20 of Set 7 | kangaatsiaq
# Processing Record 21 of Set 7 | dzhusaly
# City not found. Skipping...
# Processing Record 22 of Set 7 | portland
# Processing Record 23 of Set 7 | stornoway
# Processing Record 24 of Set 7 | ikalamavony
# Processing Record 25 of Set 7 | itaituba
# Processing Record 26 of Set 7 | poum
# Processing Record 27 of Set 7 | beitbridge
# Processing Record 28 of Set 7 | sakata
# Processing Record 29 of Set 7 | biak
# Processing Record 30 of Set 7 | souillac
# Processing Record 31 of Set 7 | richards bay
# Processing Record 32 of Set 7 | abiy adi
# City not found. Skipping...
# Processing Record 33 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 34 of Set 7 | poronaysk
# Processing Record 35 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 36 of Set 7 | klaksvik
# Processing Record 37 of Set 7 | cabo san lucas
# Processing Record 38 of Set 7 | svetlyy
# Processing Record 39 of Set 7 | neiafu
# Processing Record 40 of Set 7 | smithers
# Processing Record 41 of Set 7 | edirne
# Processing Record 42 of Set 7 | upernavik
# Processing Record 43 of Set 7 | teguise
# Processing Record 44 of Set 7 | port moresby
# Processing Record 45 of Set 7 | tautira
# Processing Record 46 of Set 7 | ilinskiy
# Processing Record 47 of Set 7 | charters towers
# Processing Record 48 of Set 7 | solenzo
# Processing Record 49 of Set 7 | kasongo-lunda
# Processing Record 50 of Set 7 | roma
# Processing Record 1 of Set 8 | sorong
# Processing Record 2 of Set 8 | ballarat
# Processing Record 3 of Set 8 | chico
# Processing Record 4 of Set 8 | timizart
# Processing Record 5 of Set 8 | kununurra
# Processing Record 6 of Set 8 | tacoronte
# Processing Record 7 of Set 8 | makakilo city
# Processing Record 8 of Set 8 | hobyo
# Processing Record 9 of Set 8 | toropets
# Processing Record 10 of Set 8 | leon valley
# Processing Record 11 of Set 8 | kano
# Processing Record 12 of Set 8 | mao
# Processing Record 13 of Set 8 | redcar
# Processing Record 14 of Set 8 | mayya
# Processing Record 15 of Set 8 | batticaloa
# Processing Record 16 of Set 8 | vestmanna
# Processing Record 17 of Set 8 | sistranda
# Processing Record 18 of Set 8 | kifri
# Processing Record 19 of Set 8 | cururupu
# Processing Record 20 of Set 8 | timra
# Processing Record 21 of Set 8 | margate
# Processing Record 22 of Set 8 | ugoofaaru
# Processing Record 23 of Set 8 | valparaiso
# Processing Record 24 of Set 8 | vung tau
# Processing Record 25 of Set 8 | yerofey pavlovich
# Processing Record 26 of Set 8 | quelimane
# Processing Record 27 of Set 8 | daru
# Processing Record 28 of Set 8 | pangai
# Processing Record 29 of Set 8 | russell
# Processing Record 30 of Set 8 | dingle
# Processing Record 31 of Set 8 | wattegama
# Processing Record 32 of Set 8 | sao joao da barra
# Processing Record 33 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 34 of Set 8 | alofi
# Processing Record 35 of Set 8 | grand-santi
# Processing Record 36 of Set 8 | vyartsilya
# Processing Record 37 of Set 8 | winnemucca
# Processing Record 38 of Set 8 | berdychiv
# Processing Record 39 of Set 8 | inhambane
# Processing Record 40 of Set 8 | choya
# Processing Record 41 of Set 8 | ahipara
# Processing Record 42 of Set 8 | aasiaat
# Processing Record 43 of Set 8 | vilaka
# Processing Record 44 of Set 8 | anshun
# Processing Record 45 of Set 8 | aljezur
# Processing Record 46 of Set 8 | lubuagan
# Processing Record 47 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 48 of Set 8 | iwanai
# Processing Record 49 of Set 8 | malakal
# Processing Record 50 of Set 8 | pimenta bueno
# Processing Record 1 of Set 9 | xam nua
# Processing Record 2 of Set 9 | agadez
# Processing Record 3 of Set 9 | makaha
# Processing Record 4 of Set 9 | zhob
# Processing Record 5 of Set 9 | waingapu
# Processing Record 6 of Set 9 | buy
# Processing Record 7 of Set 9 | mahajanga
# Processing Record 8 of Set 9 | high level
# Processing Record 9 of Set 9 | cazaje
# City not found. Skipping...
# Processing Record 10 of Set 9 | ramanuj ganj
# Processing Record 11 of Set 9 | fairfield
# Processing Record 12 of Set 9 | marathon
# Processing Record 13 of Set 9 | santa
# Processing Record 14 of Set 9 | pangody
# Processing Record 15 of Set 9 | faya
# Processing Record 16 of Set 9 | raymore
# Processing Record 17 of Set 9 | dujuma
# City not found. Skipping...
# Processing Record 18 of Set 9 | santa cruz
# Processing Record 19 of Set 9 | egvekinot
# Processing Record 20 of Set 9 | puqi
# Processing Record 21 of Set 9 | trairi
# Processing Record 22 of Set 9 | black river
# Processing Record 23 of Set 9 | luwuk
# Processing Record 24 of Set 9 | kourou
# Processing Record 25 of Set 9 | rybachiy
# Processing Record 26 of Set 9 | eldikan
# City not found. Skipping...
# Processing Record 27 of Set 9 | bajil
# Processing Record 28 of Set 9 | bubaque
# Processing Record 29 of Set 9 | noumea
# Processing Record 30 of Set 9 | catuday
# Processing Record 31 of Set 9 | leh
# Processing Record 32 of Set 9 | filingue
# Processing Record 33 of Set 9 | aswan
# Processing Record 34 of Set 9 | severo-kurilsk
# Processing Record 35 of Set 9 | san ignacio
# Processing Record 36 of Set 9 | pangnirtung
# Processing Record 37 of Set 9 | sept-iles
# Processing Record 38 of Set 9 | kamenka
# Processing Record 39 of Set 9 | rio gallegos
# Processing Record 40 of Set 9 | sorland
# Processing Record 41 of Set 9 | north platte
# Processing Record 42 of Set 9 | do rud
# City not found. Skipping...
# Processing Record 43 of Set 9 | amot
# Processing Record 44 of Set 9 | srednekolymsk
# Processing Record 45 of Set 9 | taldan
# Processing Record 46 of Set 9 | goundam
# Processing Record 47 of Set 9 | tazovskiy
# Processing Record 48 of Set 9 | maragogi
# Processing Record 49 of Set 9 | imbituba
# Processing Record 50 of Set 9 | sindor
# Processing Record 1 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 2 of Set 10 | sola
# Processing Record 3 of Set 10 | jujuy
# City not found. Skipping...
# Processing Record 4 of Set 10 | moindou
# Processing Record 5 of Set 10 | avrig
# Processing Record 6 of Set 10 | evensk
# Processing Record 7 of Set 10 | bataipora
# Processing Record 8 of Set 10 | oranjemund
# Processing Record 9 of Set 10 | ati
# Processing Record 10 of Set 10 | matata
# Processing Record 11 of Set 10 | yerbogachen
# Processing Record 12 of Set 10 | san rafael del sur
# Processing Record 13 of Set 10 | xiangfan
# Processing Record 14 of Set 10 | la ronge
# Processing Record 15 of Set 10 | taltal
# Processing Record 16 of Set 10 | fort nelson
# Processing Record 17 of Set 10 | vila
# Processing Record 18 of Set 10 | acapulco
# Processing Record 19 of Set 10 | maceio
# Processing Record 20 of Set 10 | cochrane
# Processing Record 21 of Set 10 | gerardmer
# Processing Record 22 of Set 10 | clyde river
# Processing Record 23 of Set 10 | hofn
# Processing Record 24 of Set 10 | general roca
# Processing Record 25 of Set 10 | farafangana
# Processing Record 26 of Set 10 | grand gaube
# Processing Record 27 of Set 10 | hasaki
# Processing Record 28 of Set 10 | achalpur
# Processing Record 29 of Set 10 | kendari
# Processing Record 30 of Set 10 | langangen
# City not found. Skipping...
# Processing Record 31 of Set 10 | khoy
# Processing Record 32 of Set 10 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 33 of Set 10 | port blair
# Processing Record 34 of Set 10 | muroto
# Processing Record 35 of Set 10 | usinsk
# Processing Record 36 of Set 10 | taburi
# City not found. Skipping...
# Processing Record 37 of Set 10 | akdepe
# Processing Record 38 of Set 10 | hamadan
# Processing Record 39 of Set 10 | kattivakkam
# Processing Record 40 of Set 10 | sioux lookout
# Processing Record 41 of Set 10 | belmonte
# Processing Record 42 of Set 10 | jaciara
# Processing Record 43 of Set 10 | cairns
# Processing Record 44 of Set 10 | guerrero negro
# Processing Record 45 of Set 10 | kem
# Processing Record 46 of Set 10 | eyl
# Processing Record 47 of Set 10 | waitati
# Processing Record 48 of Set 10 | bukachacha
# Processing Record 49 of Set 10 | porto novo
# Processing Record 50 of Set 10 | bilma
# Processing Record 1 of Set 11 | katangli
# Processing Record 2 of Set 11 | dandong
# Processing Record 3 of Set 11 | belur
# Processing Record 4 of Set 11 | chambas
# Processing Record 5 of Set 11 | jackson
# Processing Record 6 of Set 11 | yaan
# Processing Record 7 of Set 11 | eastbourne
# Processing Record 8 of Set 11 | labuhan
# Processing Record 9 of Set 11 | biltine
# Processing Record 10 of Set 11 | methoni
# Processing Record 11 of Set 11 | polunochnoye
# Processing Record 12 of Set 11 | arman
# Processing Record 13 of Set 11 | taree
# Processing Record 14 of Set 11 | ciras
# City not found. Skipping...
# Processing Record 15 of Set 11 | eureka
# Processing Record 16 of Set 11 | atbasar
# Processing Record 17 of Set 11 | campbellsville
# Processing Record 18 of Set 11 | aginskoye
# Processing Record 19 of Set 11 | gornyy
# Processing Record 20 of Set 11 | salalah
# Processing Record 21 of Set 11 | mapiri
# Processing Record 22 of Set 11 | tabas
# Processing Record 23 of Set 11 | sur
# Processing Record 24 of Set 11 | senneterre
# Processing Record 25 of Set 11 | imeni zhelyabova
# Processing Record 26 of Set 11 | morena
# Processing Record 27 of Set 11 | dobryanka
# Processing Record 28 of Set 11 | burnie
# Processing Record 29 of Set 11 | ambodifototra
# City not found. Skipping...
# Processing Record 30 of Set 11 | qaqortoq
# Processing Record 31 of Set 11 | senanga
# Processing Record 32 of Set 11 | astoria
# Processing Record 33 of Set 11 | inverell
# Processing Record 34 of Set 11 | thinadhoo
# Processing Record 35 of Set 11 | samagaltay
# Processing Record 36 of Set 11 | high rock
# Processing Record 37 of Set 11 | southbridge
# Processing Record 38 of Set 11 | xacmaz
# Processing Record 39 of Set 11 | semnan
# Processing Record 40 of Set 11 | bathsheba
# Processing Record 41 of Set 11 | alice springs
# Processing Record 42 of Set 11 | dalianwan
# Processing Record 43 of Set 11 | haines junction
# Processing Record 44 of Set 11 | shar
# Processing Record 45 of Set 11 | bethanien
# Processing Record 46 of Set 11 | uray
# Processing Record 47 of Set 11 | bowen
# Processing Record 48 of Set 11 | baykit
# Processing Record 49 of Set 11 | kirakira
# Processing Record 50 of Set 11 | balikpapan
# Processing Record 1 of Set 12 | tura
# Processing Record 2 of Set 12 | abu samrah
# Processing Record 3 of Set 12 | volnoye
# Processing Record 4 of Set 12 | perene
# Processing Record 5 of Set 12 | hervey bay
# Processing Record 6 of Set 12 | ayagoz
# Processing Record 7 of Set 12 | rach gia
# Processing Record 8 of Set 12 | mergui
# City not found. Skipping...
# Processing Record 9 of Set 12 | atasu
# Processing Record 10 of Set 12 | palmer
# Processing Record 11 of Set 12 | batemans bay
# Processing Record 12 of Set 12 | korla
# Processing Record 13 of Set 12 | haverfordwest
# Processing Record 14 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 15 of Set 12 | ambovombe
# Processing Record 16 of Set 12 | constantine
# Processing Record 17 of Set 12 | paamiut
# Processing Record 18 of Set 12 | creel
# Processing Record 19 of Set 12 | sao gabriel da cachoeira
# Processing Record 20 of Set 12 | tadine
# Processing Record 21 of Set 12 | el dorado
# Processing Record 22 of Set 12 | zhezkazgan
# Processing Record 23 of Set 12 | arlit
# Processing Record 24 of Set 12 | puerto penasco
# Processing Record 25 of Set 12 | chapais
# Processing Record 26 of Set 12 | vaxjo
# Processing Record 27 of Set 12 | sulangan
# Processing Record 28 of Set 12 | mandalgovi
# Processing Record 29 of Set 12 | pundaguitan
# Processing Record 30 of Set 12 | ixtapa
# Processing Record 31 of Set 12 | bachaquero
# Processing Record 32 of Set 12 | nykoping
# Processing Record 33 of Set 12 | hovd
# Processing Record 34 of Set 12 | santa rosa
# Processing Record 35 of Set 12 | san patricio
# Processing Record 36 of Set 12 | bacsay
# Processing Record 37 of Set 12 | nishihara
# Processing Record 38 of Set 12 | ous
# Processing Record 39 of Set 12 | coahuayana
# Processing Record 40 of Set 12 | tosya
# Processing Record 41 of Set 12 | olafsvik
# Processing Record 42 of Set 12 | humaita
# Processing Record 43 of Set 12 | saryozek
# Processing Record 44 of Set 12 | fez
# Processing Record 45 of Set 12 | kaili
# Processing Record 46 of Set 12 | farafenni
# Processing Record 47 of Set 12 | mahadday weyne
# City not found. Skipping...
# Processing Record 48 of Set 12 | skagastrond
# City not found. Skipping...
# Processing Record 49 of Set 12 | bykovo
# Processing Record 50 of Set 12 | maturin
# Processing Record 1 of Set 13 | preobrazheniye
# Processing Record 2 of Set 13 | zhigansk
# Processing Record 3 of Set 13 | kokopo
# Processing Record 4 of Set 13 | borba
# Processing Record 5 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 6 of Set 13 | barra do corda
# Processing Record 7 of Set 13 | jieshi
# Processing Record 8 of Set 13 | inta
# Processing Record 9 of Set 13 | altay
# Processing Record 10 of Set 13 | rurrenabaque
# Processing Record 11 of Set 13 | tezu
# Processing Record 12 of Set 13 | suoyarvi
# Processing Record 13 of Set 13 | bardiyah
# Processing Record 14 of Set 13 | varnavino
# Processing Record 15 of Set 13 | garden city
# Processing Record 16 of Set 13 | la palma
# Processing Record 17 of Set 13 | japura
# Processing Record 18 of Set 13 | ames
# Processing Record 19 of Set 13 | male
# Processing Record 20 of Set 13 | kenai
# Processing Record 21 of Set 13 | synya
# Processing Record 22 of Set 13 | qena
# Processing Record 23 of Set 13 | verkhoyansk
# Processing Record 24 of Set 13 | camocim
# Processing Record 25 of Set 13 | barras
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 571

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Mahebourg -20.4081   57.7000     68.29        83          75
# 1        Torbay  47.6666  -52.7314     33.58        77         100
# 2  Oktyabrskoye  43.0645   44.7417     28.54        93         100
# 3           Bam  29.1060   58.3570     59.83        38           2
# 4       Toumodi   6.5613   -5.0158     69.24        78          32
# 5       Isangel -19.5500  169.2667     82.89        64          94
# 6   Port Alfred -33.5906   26.8910     62.19        95          67
# 7      Hamilton  39.1834  -84.5333     35.91        78         100
# 8        Harper   4.3750   -7.7169     77.67        85           8
# 9   East London -33.0153   27.9116     65.70        80          84
#
#    Wind Speed Country       Description
# 0        2.30      MU     broken clouds
# 1        9.22      CA   overcast clouds
# 2        4.47      RU   overcast clouds
# 3        3.13      IR         clear sky
# 4        3.67      CI  scattered clouds
# 5        6.80      VU   overcast clouds
# 6        3.00      ZA     broken clouds
# 7       11.50      US   overcast clouds
# 8        7.05      LR         clear sky
# 9        2.91      ZA     broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df = city_data_df.rename(columns={"Description": "Current Description"})
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_weather = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_weather]

# Display sample data
city_data_df
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Mahebourg      MU -20.4081   57.7000     68.29        83          75
# 1          Torbay      CA  47.6666  -52.7314     33.58        77         100
# 2    Oktyabrskoye      RU  43.0645   44.7417     28.54        93         100
# 3             Bam      IR  29.1060   58.3570     59.83        38           2
# 4         Toumodi      CI   6.5613   -5.0158     69.24        78          32
# ..            ...     ...      ...       ...       ...       ...         ...
# 566         Synya      RU  65.3718   58.0387    -14.13        94           7
# 567          Qena      EG  26.1615   32.7183     65.35        45         100
# 568   Verkhoyansk      RU  67.5447  133.3850    -41.31       100          75
# 569       Camocim      BR  -2.9022  -40.8411     78.69        77          12
# 570        Barras      BR  -4.2444  -42.2944     79.45        65          26
#
#      Wind Speed Current Description
# 0          2.30       broken clouds
# 1          9.22     overcast clouds
# 2          4.47     overcast clouds
# 3          3.13           clear sky
# 4          3.67    scattered clouds
# ..          ...                 ...
# 566        5.64           clear sky
# 567        5.57     overcast clouds
# 568        1.21       broken clouds
# 569       12.33          few clouds
# 570        7.49    scattered clouds
#
# [571 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_file = 'WeatherPy_Database.csv'

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_file)
